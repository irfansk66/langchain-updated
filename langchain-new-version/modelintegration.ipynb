# %% [markdown]
# # LangChain Model Integration Guide
#
# This notebook demonstrates how to integrate different LLM providers using LangChain.

# %%
# 1. Load environment variables
import os
from dotenv import load_dotenv

load_dotenv("../.env")

# %%
# 2. Groq Integration (ACTIVE & WORKING)
from langchain_groq import ChatGroq

# Active key verified in .env
groq_llm = ChatGroq(model="llama-3.3-70b-versatile")

response = groq_llm.invoke("Hello! Introduce yourself briefly.")
print("Groq Response:")
print(response.content)

# %%
# 3. Google Gemini Integration (Quota Exceeded - Error 429)
# Note: Your Google API key currently has 0 free tier quota remaining.
# Enable billing or wait for quota reset at https://ai.google.dev/gemini-api/docs/rate-limits

# from langchain_google_genai import ChatGoogleGenerativeAI
# gemini_llm = ChatGoogleGenerativeAI(model="gemini-2.0-flash")
# print(gemini_llm.invoke("Hello!").content)

# %%
# 4. OpenAI Integration (Quota Exceeded - Error 429)
# Note: Your OpenAI API key requires adding credits at https://platform.openai.com/account/billing

# from langchain_openai import ChatOpenAI
# openai_llm = ChatOpenAI(model="gpt-4o-mini")
# print(openai_llm.invoke("Hello!").content)
